# %% [markdown]
# ### Copy this notebook to your data directory. The sys.path command below will add the Useful Code directory to allow importing code from there.

# %%
# %matplotlib notebook

import h5py
from numpy import *
import os
import sys
sys.path.append("Z:\\Public\\Hybrid\\Useful Code\\Python\\")
import matplotlib.pyplot as plt
import scipy.optimize as opt
import counterh5 as ch5
import seaborn as sbs
sbs.reset_orig()
import imageh5 as i5
from imageh5 import seedpermute

# %%
mydir=os.getcwd()
print mydir
imageH5 = i5.ImageH5(mydir, '1026', 0)
#imageH5 = i5.ImageH5(mydir, '329', 1)
# Out:
# E:\Data\Measurements\2020_09_01\2020_09_01_18_32_45_PGC1_ShimZ
# 0
# Z:\Public\Hybrid\Useful Code\Python\imageh5.py:95: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   return h5py.File(filename)

# %%
imageH5.imagefunction = imageH5.imagefromh5
axforscale = imageH5.showGraphNoContours(0)
# Out:
# max: 944.882352941, mean: 712.675287908
# <img src="data:image/png;base64,..." width="640">

# %%
imageH5.PixelSize=4.7e-6

# %%
imageH5.getLimits(axforscale)
imageH5.oneDIntegrationFit(showGraphs=True)
# Out:
# ROI limits are
#  x:0,399
#  y:0,599
#
# Fitting 1D to Iteration 0
# [2.45294465e+04 3.39694097e+02 1.99154141e+02 2.70355773e+05
#  1.31176829e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 1
# [2.53225534e+04 3.43157875e+02 1.97839080e+02 2.70916254e+05
#  1.32606393e+01]
# Z:\Public\Hybrid\Useful Code\Python\imageh5.py:501: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(True)
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 2
# [2.68669298e+04 3.45123983e+02 1.97871944e+02 2.71821151e+05
#  1.35067709e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 3
# [2.49967912e+04 3.40861956e+02 1.97992629e+02 2.70640519e+05
#  1.31861759e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 4
# [2.50776260e+04 3.39727824e+02 1.98716370e+02 2.70970845e+05
#  1.32014518e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 5
# [2.51118136e+04 3.39614666e+02 1.99420812e+02 2.70712462e+05
#  1.31326749e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 6
# [2.51527249e+04 3.40103647e+02 1.98509469e+02 2.70405861e+05
#  1.29038091e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 7
# [2.52416142e+04 3.38891750e+02 2.00076704e+02 2.70794993e+05
#  1.28076727e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 8
# [2.53698611e+04 3.39114644e+02 1.98664323e+02 2.70900915e+05
#  1.29368180e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 9
# [2.74648468e+04 3.45689870e+02 1.98296193e+02 2.71845600e+05
#  1.30541121e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 10
# [2.73578632e+04 3.42907892e+02 1.98384430e+02 2.72184402e+05
#  1.31876593e+01]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 0
# [ 3.56330687e+04  2.31659352e+02  1.81404247e+02  4.47203979e+05
#  -1.99519596e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 1
# [ 3.65545727e+04  2.32118015e+02  1.81122225e+02  4.48449989e+05
#  -2.01665792e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 2
# [ 3.82980426e+04  2.31944708e+02  1.81634505e+02  4.50501566e+05
#  -2.04855648e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 3
# [ 3.62952386e+04  2.31848103e+02  1.81012502e+02  4.47828680e+05
#  -2.00978030e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 4
# [ 3.63601732e+04  2.31791847e+02  1.79840473e+02  4.48648376e+05
#  -2.01683944e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 5
# [ 3.66001251e+04  2.31903177e+02  1.80189255e+02  4.48017639e+05
#  -2.01052611e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 6
# [ 3.63667195e+04  2.32167963e+02  1.80184571e+02  4.47348264e+05
#  -2.00081705e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 7
# [ 3.65341827e+04  2.31826703e+02  1.79804815e+02  4.48304388e+05
#  -2.01589343e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 8
# [ 3.67544396e+04  2.31879976e+02  1.79596190e+02  4.48379360e+05
#  -2.01518017e+02]
# c:\users\hybrid\envs\analysis\lib\site-packages\matplotlib\pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 9
# [ 3.93678834e+04  2.32380967e+02  1.79818262e+02  4.50312244e+05
#  -2.04741036e+02]
# <img src="data:image/png;base64,..." width="640">
# Fitting 1D to Iteration 10
# [ 3.95836081e+04  2.32308781e+02  1.80712352e+02  4.50912302e+05
#  -2.06199276e+02]
# <img src="data:image/png;base64,..." width="640">
# (array([[2.45294465e+04, 2.31659352e+02, 3.39694097e+02, 1.81404247e+02,
#          1.99154141e+02, 4.47203979e+05, 2.70355773e+05, 3.56330687e+04],
#         [2.53225534e+04, 2.32118015e+02, 3.43157875e+02, 1.81122225e+02,
#          1.97839080e+02, 4.48449989e+05, 2.70916254e+05, 3.65545727e+04],
#         [2.68669298e+04, 2.31944708e+02, 3.45123983e+02, 1.81634505e+02,
#          1.97871944e+02, 4.50501566e+05, 2.71821151e+05, 3.82980426e+04],
#         [2.49967912e+04, 2.31848103e+02, 3.40861956e+02, 1.81012502e+02,
#          1.97992629e+02, 4.47828680e+05, 2.70640519e+05, 3.62952386e+04],
#         [2.50776260e+04, 2.31791847e+02, 3.39727824e+02, 1.79840473e+02,
#          1.98716370e+02, 4.48648376e+05, 2.70970845e+05, 3.63601732e+04],
#         [2.51118136e+04, 2.31903177e+02, 3.39614666e+02, 1.80189255e+02,
#          1.99420812e+02, 4.48017639e+05, 2.70712462e+05, 3.66001251e+04],
#         [2.51527249e+04, 2.32167963e+02, 3.40103647e+02, 1.80184571e+02,
#          1.98509469e+02, 4.47348264e+05, 2.70405861e+05, 3.63667195e+04],
#         [2.52416142e+04, 2.31826703e+02, 3.38891750e+02, 1.79804815e+02,
#          2.00076704e+02, 4.48304388e+05, 2.70794993e+05, 3.65341827e+04],
#         [2.53698611e+04, 2.31879976e+02, 3.39114644e+02, 1.79596190e+02,
#          1.98664323e+02, 4.48379360e+05, 2.70900915e+05, 3.67544396e+04],
#         [2.74648468e+04, 2.32380967e+02, 3.45689870e+02, 1.79818262e+02,
#          1.98296193e+02, 4.50312244e+05, 2.71845600e+05, 3.93678834e+04],
#         [2.73578632e+04, 2.32308781e+02, 3.42907892e+02, 1.80712352e+02,
#          1.98384430e+02, 4.50912302e+05, 2.72184402e+05, 3.95836081e+04]]),
#  array([[315.46958455,   0.56255774,   1.74312575, 211.35687056,
#            1.02505901],
#         [333.56324818,   0.57938893,   1.79041656, 221.04156718,
#            1.08828445],
#         [332.95421152,   0.55141891,   1.70739235, 221.42364559,
#            1.08164251],
#         [335.21195693,   0.58721281,   1.81627512, 223.66378442,
#            1.09308519],
#         [329.13443747,   0.57787883,   1.78277614, 220.30407148,
#            1.08150122],
#         [339.51353472,   0.59124719,   1.8246919 , 226.49406287,
#            1.11354939],
#         [314.64782554,   0.5509302 ,   1.69831119, 208.53866639,
#            1.03331037],
#         [311.23764519,   0.54382789,   1.67733772, 208.14901355,
#            1.02309016],
#         [312.75207996,   0.54345924,   1.67497874, 208.95486566,
#            1.02976413],
#         [338.53240825,   0.54774114,   1.68548598, 223.2979468 ,
#            1.11555387],
#         [345.35828139,   0.55429619,   1.70978086, 227.90119664,
#            1.13087347]]),
#  array([[134.16019082,   0.57825659,   1.56235605, 112.77591529,
#            0.35131293],
#         [138.41929555,   0.57171986,   1.54530573, 112.75989145,
#            0.36570995],
#         [147.33633635,   0.57068118,   1.54582315, 117.81837466,
#            0.39138428],
#         [136.72709301,   0.57546108,   1.55234808, 113.75073934,
#            0.35901665],
#         [137.80679479,   0.58046668,   1.56677137, 115.81599224,
#            0.36084853],
#         [138.65994701,   0.58418638,   1.57924437, 116.63677926,
#            0.36304371],
#         [136.42402175,   0.57220452,   1.54427514, 114.26798575,
#            0.35756064],
#         [140.26320979,   0.58958191,   1.59525627, 118.75641327,
#            0.3665939 ],
#         [137.90481472,   0.5749313 ,   1.55075185, 116.54425822,
#            0.36051425],
#         [151.20997633,   0.5724698 ,   1.55302863, 120.20884973,
#            0.40235215],
#         [150.92969893,   0.57795056,   1.56364989, 123.19442326,
#            0.3985637 ]]))

# %%
imageH5.getTemperaturesXY(dropFrames=0,dropStartFrames=0)
# Out:
# Real Pixel Width: 4.7e-06 m
# xlin: (11L,)
# cloudWidthsX: (11L,)
# X dimension fit
# Temperature: -170.91037319 microKelvin
# <img src="data:image/png;base64,..." width="640">
# Y dimension fit
# Temperature: 35.8623279688 microKelvin
# Z:\Public\Hybrid\Useful Code\Python\imageh5.py:604: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(True)
# <img src="data:image/png;base64,..." width="640">
# (-170.91037319000733, 35.8623279687943)

# %%
allpopts = imageH5.allpopts
x_centers = allpopts[:,1]
y_centers = allpopts[:,2]
fig,axes = plt.subplots(2,1)
axes[0].plot(imageH5.iVarVals,x_centers)
axes[0].plot(imageH5.iVarVals,zeros_like(imageH5.iVarVals)+225.6)
axes[0].set_title("X centers")
axes[0].set_xlabel(imageH5.iVars[0][0])
axes[0].set_ylabel("Center Position (pixel no)")
axes[1].plot(imageH5.iVarVals,y_centers)
axes[1].plot(imageH5.iVarVals,zeros_like(imageH5.iVarVals)+313.6)
axes[1].set_title("Y centers")
axes[1].set_xlabel(imageH5.iVars[0][0])
axes[1].set_ylabel("Center Position (pixel no)")
fig.tight_layout()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(imageH5.iVarVals)
# Out:
# [(-0.25,), (-0.2,), (-0.15,), (-0.09999999999999998,), (-0.04999999999999999,), (0.0,), (0.050000000000000044,), (0.10000000000000003,), (0.15000000000000002,), (0.2,), (0.25,)]

# %%
for i in imageH5.resultsfile['settings/experiment/independentVariables/'].iteritems():
    print (i[0], i[1]['function'].value, i[1]['description'].value)
# Out:
# (u'AerotechZPos', '4.45', 'Vertical Position of Aerotech stage (mm)')
# (u'AnalogGain', '1', 'AnalogGainForHamamtsu')
# (u'AndorExpT', '50', 'Exposure Time for andor camera (ms)')
# (u'BAChop', 'False', 'Chop During Blowaway')
# (u'BA_Power', '0', 'Blowaway Power (dBm)')
# (u'Blow_Away_time', '2', 'Time for blowaway (ms)')
# (u'CONEXFocus', '3.35', 'Focal Position of Lux Mux (mm)')
# (u'CONEXHoriz', '2.4071', 'Horizontal Position of Conex Stage (mm)')
# (u'DoChop', 'False', 'Toggles chopping during PGC and RO')
# (u'DropTime', '0', 'Time to Drop FORT (us)')
# (u'Drop_Time', 'linspace(2,5,11)', 'Time Between Dropping The MOT and RO')
# (u'GapTime', '10', 'Time between imaging pulses (ms)')
# (u'ImageDelay', '0', 'Image Delay')
# (u'LAC_D2_detuning', '-3.0', 'Detuning during LAC (Gamma)')
# (u'LAC_D2_power', '0', 'Power during LAC pulse')
# (u'LAC_Time', '40*0', 'Duration of LAC')
# (u'LAC_hyperfine_power', '2.6', 'Repumper Power during LAC')
# (u'LAC_shim_X', '0.1', 'LAC Shim, X Component')
# (u'LAC_shim_Y', '0.01', 'LAC Shim, Y Component')
# (u'LAC_shim_Z', '-.22', 'LAC Shim, Z Component')
# (u'MOT_Andor_Gain', '200', 'EM Gain for MOT Andor Camera ')
# (u'MOT_Background', 'True', 'Boolean to take MOT background')
# (u'MOT_Coil_Current', '15.4972563782', 'MOT Coil Current (A)')
# (u'MOT_loading_time', '150', 'MOT loading time (ms)')
# (u'MOT_shim_X', '-0.562', 'MOT Shim X (A)')
# (u'MOT_shim_Y', '.241', 'MOT Shim Y (A)')
# (u'MOT_shim_Z', '-.55', 'MOT Shim Z (A)')
# (u'MOT_shutter_enable', 'True', 'False to Block MOT light, True to unblock')
# (u'MuxJrFocus', '6.18', 'Focal Position of Lux Mux Jr (mm)')
# (u'MuxJrHoriz', '7.239', 'Horizontal Position of LuxMuxJr (mm)')
# (u'MuxJrVert', '11.615*0+5.66', 'Vertical Position of LuxMuxJr (mm)')
# (u'OP_HF_amplitude', '2.6', 'Repumper amplitude for OP (V)')
# (u'OP_Time', '10', 'Optical Pumping Time (ms)')
# (u'OP_chop', 'False', 'Trap Chopping Enabled on Optical Pumping')
# (u'OP_depump', 'True', 'Enable Depump step')
# (u'OP_detuning', '25*0+30', 'Optical Pumping AOM Detuning (MHz)')
# (u'OP_power', '0', 'Optical Pumping Power (dBm)')
# (u'OP_shelve_time', '0', 'Shelving time during OP phase (ms)')
# (u'OP_shim_X_offset', '2', 'Optical Pumping Shim X (A)')
# (u'OP_shim_Y_offset', '0.4*0', 'Optical Pumping Shim Y (A)')
# (u'OP_shim_Z_offset', '0*0', 'Optical Pumping Shim Z (A)')
# (u'PGC1_ShimX', '0.219', 'PGC1_ShimX')
# (u'PGC1_ShimY', '0.21', 'PGC1_ShimY')
# (u'PGC1_ShimZ', '-0.263', 'PGC1_ShimZ')
# (u'PGC2_ShimX', '.18', 'Shim X in PGC2 (A)')
# (u'PGC2_ShimY', '-.14', 'Shim Y in PGC2 (A)')
# (u'PGC2_ShimZ', '1.71*0+2.4', 'Shim Z in PGC2 (A)')
# (u'PGC_1_D2_detuning', '-6', 'PGC Detuning for FORT loading (Gamma)')
# (u'PGC_1_D2_power', '-3', 'PGC_1_D2_Power')
# (u'PGC_1_hyperfine_power', '2.6', 'PGC 1 Hyperfine Power')
# (u'PGC_1_time', '0', 'PGC_1_time')
# (u'PGC_2_D2_detuning', '-10', 'Detuning from D2 Cooling Transition (gamma)')
# (u'PGC_2_D2_power', '-3', 'Power in D2 beam (dBm)')
# (u'PGC_2_time', '10*0', 'Time for PGC2 (ms)')
# (u'RO1_D2_Power', '-1.46580286662', 'Readout Power (dBm)')
# (u'RO1_D2_detuning', '-3.66061990526', 'Readout Detuning (Gamma)')
# (u'RO1_hyperfine_power', '.5*0+1.5', 'Repumper Power During Readout')
# (u'RO1_shim_X', '0.2691', 'Readout Shim X')
# (u'RO1_shim_Y', '-.1', 'Readout Shim Y')
# (u'RO1_shim_Z', '0.0484206792712*0-.263', 'Readout Shim Z')
# (u'ROShimTimeOffset', '0', 'RO Shim Time Offset')
# (u'RO_Time', '60*0+10', 'Readout time (ms)')
# (u'RamseyTime', '0', 'Time in between pi/2 pulses in Ramsey Experiment(ms)')
# (u'Recool_D2_detuning', '-10', 'D2 detuning during recooling phase')
# (u'Recool_D2_power', '-3', 'D2 power during recooling phase (dBm)')
# (u'Recool_hyperfine_power', '2.6', 'HF power during recooling phase (V)')
# (u'Recool_shim_X', '0.1', 'Recool shim, x-component')
# (u'Recool_shim_Y', '0.01', 'Recool shim, y-component')
# (u'Recool_shim_Z', '-.22', 'Recool shim, z-component')
# (u'Recool_time', '40*0', 'Length of Recooling Phase (ms)')
# (u'Ryd_595_frequency', '471', 'Frequency offset for 595nm lock (MHz)')
# (u'SPCM_gates', '54', 'SPCM gates During readout')
# (u'Shots', '2', 'Number of Shots')
# (u'ShuttersOn', 'True', 'Toggle to enable/disable shutter function')
# (u'Trap_Hold_time', '4', 'Hold time in between loading and imaging (ms)')
# (u'closeXShutter', '1*0', 'Close X shutter during RO')
# (u'closeXZShutter', '0', 'Toggle to close XZ Shutter during RO')
# (u'closeY2Shutter', '0', 'Toggle to close Y2 Shutter during RO')
# (u'closeYShutter', '1*0', 'Toggle to close Y Shutter during RO')
# (u'hODT_delay', '1000', 'Time before Trap On')
# (u'pre_uW_time', '1', 'Time before microwave pulse (ms)')
# (u'shelve_state', '4', 'Hyperfine level to shelve into')
# (u'shelve_time', '10', 'Time for hyperfine shelving (ms)')
# (u'uW_detuning', '6.0e-3', 'Microwave Detuning from Cs HF (MHz)')
# (u'uW_time', '0.041*0', 'Microwave pulse time (ms)')
# (u'uWchop', 'False', 'uWave chopping boolean')
# (u'vertTrapPower', '0.45221*0+0.475', 'Power in Vertical Translation Trap (V)')
# (u'whichShutter', '0', 'Which Shutter is open? (x=1,y=2,z=3)')
# c:\users\hybrid\envs\analysis\lib\site-packages\ipykernel_launcher.py:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %%
import datetime
import shutil
import re
import os
import operator

volume = os.getcwd()[0]

if (os.name == 'posix'):
    path = "/Volumes/D/Public/Hybrid/Data/Measurements/"
    pathSeperator = "/"
elif volume == 'E':
    path = "E:\\Data\\Measurements\\"
    pathSeperator = "\\"
elif volume == 'Z':
    path = "Z:\\Public\\Hybrid\\Data\\Measurements\\"
    pathSeperator = "\\"

#removes hidden files from the file lists that we import
def cleanList(fileList):
    return [f for f in fileList if '.' not in f[0]]
    
today = datetime.date.today()+datetime.timedelta(10)
fileName = "MOT_Temperature.ipynb"
dayFileList = cleanList(os.listdir(path))


def mostRecentDay(fileList,today):
    
    findDay = re.compile(str(today.year)+"_0*"+str(today.month)+"_"+str(today.day))
    
    for f in fileList:
        match = findDay.match(f)
        if match:
            #found match
            return f,today
        
    #onle here if we never find anything
    #recursively look back through the days
    yesterday = today-datetime.timedelta(1)
    return mostRecentDay(fileList,yesterday)



def recentMeasurements(today,path,dayFileList,reverse = False):
    
    
    mostRecentDayFolder,recentDay = mostRecentDay(dayFileList,today)
    dataFileList = cleanList(os.listdir(path+mostRecentDayFolder))
    
    findFile = re.compile("\w*" + str(recentDay.day)+"_(\d\d)_(\d\d)_(\d\d)_")
    
    fileDict = {}    
    for f in dataFileList:
        matches = findFile.match(f)
        #add to dict all of the properties of the regex match
        if matches:
            fileDict[f] = matches.group(0)

    #now sort the fileDict based on the regex attributes
    fileDict = sorted(fileDict.items(),key=operator.itemgetter(1),reverse = reverse)    
            
    
    return fileDict,mostRecentDayFolder


def copyFrom(today,path,dayFileList,fileName = 'MOT_Temperature.ipynb'):
    
    files,mostRecentDayFolder = recentMeasurements(today,path,dayFileList,reverse = True)
    for f,d in files:
        
        insideFiles = cleanList(os.listdir(path+mostRecentDayFolder+pathSeperator+f))
        
        if fileName in insideFiles:
            #we can copy from this file
            return path+mostRecentDayFolder+pathSeperator+f
    #theere is no analysis, keep looking
    return copyFrom(today-datetime.timedelta(1),path,dayFileList)
        
def copyTo(today,path,dayFileList,fileName = 'MOT_Temperature.ipynb'):
    
    files,mostRecentDayFolder = recentMeasurements(today,path,dayFileList,reverse = False)
    
    for f,d in files:
        insideFiles = cleanList(os.listdir(path+mostRecentDayFolder+pathSeperator+f))
        if fileName not in insideFiles:
            #we can copy to this file
            return path+mostRecentDayFolder+pathSeperator+f
    return None

# @Bradley why is this in a while loop? -Juan
while True:
    pathToCopyTo =  copyTo(today,path,dayFileList)
    pathToCopyFrom = copyFrom(today,path,dayFileList)

    if pathToCopyTo is not None:

        shutil.copy(pathToCopyFrom+pathSeperator+fileName,pathToCopyTo)
        print "Successfully copied from %s to %s"%(pathToCopyFrom, pathToCopyTo)
    else:
        print "No Path to copy to. Analysis file probably already there."
        break
# Out:
# No Path to copy to. Analysis file probably already there.

# %% [markdown]
# These two commands copy the notebook to the experiment directory.

# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# IPython.notebook.save_notebook()
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
import shutil
mypath = "Z:\\Public\\Hybrid"+NOTEBOOK_FULL_PATH.replace('/','\\')
shutil.copy2(mypath,"Z:\\Public\\Hybrid\\Data\\Measurements/{}".format(today))
print "Z:\\Public\\Hybrid\\Data\\Measurements\\{}".format(today)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a23d49e882ce> in <module>()
#       1 import shutil
# ----> 2 mypath = "Z:\\Public\\Hybrid"+NOTEBOOK_FULL_PATH.replace('/','\\')
#       3 shutil.copy2(mypath,"Z:\\Public\\Hybrid\\Data\\Measurements/{}".format(today))
#       4 print "Z:\\Public\\Hybrid\\Data\\Measurements\\{}".format(today)
#
# NameError: name 'NOTEBOOK_FULL_PATH' is not defined
